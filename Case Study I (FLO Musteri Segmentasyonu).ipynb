# %% [markdown]
# # FLO | RFM Analizi ile Müşteri Segmentasyonu

# %% [markdown]
# ## Görev 1: Veriyi Anlama ve Hazırlama

# %% [markdown]
# ### Adım 1: flo_data_20k.csv verisini okuyunuz. Dataframe'in kopyasını oluşturunuz.

# %%
import datetime as dt
import pandas as pd

# %%
df_ = pd.read_csv(r"C:\Users\myboz\development\miuul\crm_analytics\FLO_Musteri_Segmentasyonu\flo_data_20k.csv")

# %%
df = df_.copy()

# %% [markdown]
# ### Adım 2: Veri setinde ilk 10 gözlem, değişken isimleri, betimsel istatistik, boş değer, değişken tipleri incelemesi yapınız.

# %%
# İlk 10 gözlem.
df.head(10)
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# 5  e585280e-aae1-11e9-a2fc-000d3a38a36f       Desktop            Offline
# 6  c445e4ee-6242-11ea-9d1a-000d3a38a36f   Android App        Android App
# 7  3f1b4dc8-8a7d-11ea-8ec0-000d3a38a36f        Mobile            Offline
# 8  cfbda69e-5b4f-11ea-aca7-000d3a38a36f   Android App        Android App
# 9  1143f032-440d-11ea-8b43-000d3a38a36f        Mobile             Mobile
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# ...

# %%
# Değişken isimleri.
df.columns.to_list()
# Out:
# ['master_id',
#  'order_channel',
#  'last_order_channel',
#  'first_order_date',
#  'last_order_date',
#  'last_order_date_online',
#  'last_order_date_offline',
#  'order_num_total_ever_online',
#  'order_num_total_ever_offline',
#  'customer_value_total_ever_offline',
#  'customer_value_total_ever_online',
#  'interested_in_categories_12']

# %%
# Betimsel istatistik
df.describe().T
# Out:
#                                      count        mean         std    min  \
# order_num_total_ever_online        19945.0    3.110855    4.225647   1.00
# order_num_total_ever_offline       19945.0    1.913913    2.062880   1.00
# customer_value_total_ever_offline  19945.0  253.922597  301.532853  10.00
# customer_value_total_ever_online   19945.0  497.321690  832.601886  12.99
#
#                                       25%     50%     75%       max
# order_num_total_ever_online          1.00    2.00    4.00    200.00
# order_num_total_ever_offline         1.00    1.00    2.00    109.00
# customer_value_total_ever_offline   99.99  179.98  319.97  18119.14
# customer_value_total_ever_online   149.98  286.46  578.44  45220.13

# %%
# Boş değer
df.isnull().sum()
# Out:
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  object
#  4   last_order_date                    19945 non-null  object
#  5   last_order_date_online             19945 non-null  object
#  6   last_order_date_offline            19945 non-null  object
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
# ...

# %% [markdown]
# ### Adım 3: Omnichannel müşterilerin hem online hem de offline platformdan alışveriş yaptığını ifade etmektedir. Her bir müşterinin toplam alışveriş sayısı ve harcaması için yeni değişkenler oluşturunuz.

# %%
df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                          4.0
# 1              2020-01-10                         19.0
# ...

# %%
df['total_order_num'] = df['order_num_total_ever_online'] + df['order_num_total_ever_offline']
df['total_customer_value'] = df['customer_value_total_ever_online'] + df['customer_value_total_ever_offline']

# %%
df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                          4.0
# 1              2020-01-10                         19.0
# ...

# %% [markdown]
# ### Adım 4: Değişken tiplerini inceleyiniz. Tarih ifade eden değişkenlerin tipini date'e çeviriniz.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  object
#  4   last_order_date                    19945 non-null  object
#  5   last_order_date_online             19945 non-null  object
#  6   last_order_date_offline            19945 non-null  object
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
# ...

# %%
df[['first_order_date', 'last_order_date', 'last_order_date_online', 'last_order_date_offline']] = df[['first_order_date', 'last_order_date', 'last_order_date_online', 'last_order_date_offline']].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  datetime64[ns]
#  4   last_order_date                    19945 non-null  datetime64[ns]
#  5   last_order_date_online             19945 non-null  datetime64[ns]
#  6   last_order_date_offline            19945 non-null  datetime64[ns]
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
# ...

# %% [markdown]
# ### Adım 5: Alışveriş kanallarındaki müşteri sayısının, toplam alınan ürün sayısının ve toplam harcamaların dağılımına bakınız.

# %%
df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                          4.0
# 1              2020-01-10                         19.0
# ...

# %%
# Alışveriş kanallarındaki müşteri sayısının dağılımı.
df.groupby('order_channel')['master_id'].nunique()
# Out:
# order_channel
# Android App    9495
# Desktop        2735
# Ios App        2833
# Mobile         4882
# Name: master_id, dtype: int64

# %%
# Alışveriş kanallarına göre toplam alışveriş sayısı.
df.groupby('order_channel')['total_order_num'].sum()
# Out:
# order_channel
# Android App    52269.0
# Desktop        10920.0
# Ios App        15351.0
# Mobile         21679.0
# Name: total_order_num, dtype: float64

# %%
# Alışveriş kanallarına göre toplam harcama miktarı.
df.groupby('order_channel')['total_customer_value'].sum()
# Out:
# order_channel
# Android App    7819062.76
# Desktop        1610321.46
# Ios App        2525999.93
# Mobile         3028183.16
# Name: total_customer_value, dtype: float64

# %% [markdown]
# ### Adım 6: En fazla kazancı getiren ilk 10 müşteriyi sıralayınız.

# %%
df.sort_values('total_customer_value', ascending = False).head(10)
# Out:
#                                   master_id order_channel last_order_channel  \
# 11150  5d1c466a-9cfd-11e9-9897-000d3a38a36f   Android App            Desktop
# 4315   d5ef8058-a5c6-11e9-a2fc-000d3a38a36f   Android App        Android App
# 7613   73fd19aa-9e37-11e9-9897-000d3a38a36f       Ios App            Offline
# 13880  7137a5c0-7aad-11ea-8f20-000d3a38a36f       Ios App            Offline
# 9055   47a642fe-975b-11eb-8c2a-000d3a38a36f   Android App            Offline
# 7330   a4d534a2-5b1b-11eb-8dbd-000d3a38a36f       Desktop            Desktop
# 8068   d696c654-2633-11ea-8e1c-000d3a38a36f       Ios App            Ios App
# 163    fef57ffa-aae6-11e9-a2fc-000d3a38a36f        Mobile            Desktop
# 7223   cba59206-9dd1-11e9-9897-000d3a38a36f   Android App        Android App
# 18767  fc0ce7a4-9d87-11e9-9897-000d3a38a36f       Desktop            Desktop
#
#       first_order_date last_order_date last_order_date_online  \
# ...

# %% [markdown]
# ### Adım 7: En fazla sipariş veren ilk 10 müşteriyi sıralayınız.

# %%
df.sort_values('total_order_num', ascending = False).head(10)
# Out:
#                                   master_id order_channel last_order_channel  \
# 11150  5d1c466a-9cfd-11e9-9897-000d3a38a36f   Android App            Desktop
# 7223   cba59206-9dd1-11e9-9897-000d3a38a36f   Android App        Android App
# 8783   a57f4302-b1a8-11e9-89fa-000d3a38a36f   Android App            Offline
# 2619   fdbe8304-a7ab-11e9-a2fc-000d3a38a36f   Android App            Offline
# 6322   329968c6-a0e2-11e9-a2fc-000d3a38a36f       Ios App            Ios App
# 7613   73fd19aa-9e37-11e9-9897-000d3a38a36f       Ios App            Offline
# 9347   44d032ee-a0d4-11e9-a2fc-000d3a38a36f        Mobile             Mobile
# 10954  b27e241a-a901-11e9-a2fc-000d3a38a36f        Mobile             Mobile
# 8068   d696c654-2633-11ea-8e1c-000d3a38a36f       Ios App            Ios App
# 7330   a4d534a2-5b1b-11eb-8dbd-000d3a38a36f       Desktop            Desktop
#
#       first_order_date last_order_date last_order_date_online  \
# ...

# %% [markdown]
# ### Adım 8: Veri ön hazırlık sürecini fonksiyonlaştırınız.

# %%
def data_prep(df):
    # Data Info
    print('**************** DATA INFO ****************')
    df.head(10)
    df.columns.to_list()
    df.describe().T
    df.isnull().sum()
    df.info()
    print('**************** DATA INFO ****************')
    
    # Data Prep
    df['total_order_num'] = df['order_num_total_ever_online'] + df['order_num_total_ever_offline']
    df['total_customer_value'] = df['customer_value_total_ever_online'] + df['customer_value_total_ever_offline']
    df[df.columns[df.columns.str.contains('date')]] = df[df.columns[df.columns.str.contains('date')]].apply(pd.to_datetime)
    
    # Data Key Info
    # Alışveriş kanallarındaki müşteri sayısının dağılımı.
    df.groupby('order_channel')['master_id'].nunique()
    # Alışveriş kanallarına göre toplam alışveriş sayısı.
    df.groupby('order_channel')['total_order_num'].sum()
    # Alışveriş kanallarına göre toplam harcama miktarı.
    df.groupby('order_channel')['total_customer_value'].sum()

# %% [markdown]
# ## Görev 2: RFM Metriklerinin Hesaplanması

# %% [markdown]
# ### Adım 1: Recency, Frequency, Monetary tanımlarını yapınız.

# %% [markdown]
# ### Adım 2: Müşteri özelinde Recency, Frequency ve Monetary metriklerini hesaplayınız.

# %% [markdown]
# ### Adım 3: Hesapladığınız metrikleri rfm isimli bir değişkene atayınız.

# %% [markdown]
# ### Adım 4: Oluşturduğunuz metriklerin isimlerini recency, frequency ve monetary olarak değiştiriniz.

# %%
df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                          4.0
# 1              2020-01-10                         19.0
# ...

# %%
df['last_order_date'].max()
# Out:
# Timestamp('2021-05-30 00:00:00')

# %%
today_date = dt.datetime(2021, 6, 1); today_date
# Out:
# datetime.datetime(2021, 6, 1, 0, 0)

# %%
rfm = pd.DataFrame()
rfm['customer_id'] = df['master_id']
rfm['recency'] = (today_date - df['last_order_date']).astype('timedelta64[D]')
rfm['frequency'] = df['total_order_num']
rfm['monetary'] = df['total_customer_value']

# %%
rfm.head()
# Out:
#                             customer_id  recency  frequency  monetary
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f     95.0        5.0    939.37
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f    105.0       21.0   2013.55
# 2  69b69676-1a40-11ea-941b-000d3a38a36f    186.0        5.0    585.32
# 3  1854e56c-491f-11eb-806e-000d3a38a36f    135.0        2.0    121.97
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f     86.0        2.0    209.98

# %%
rfm.describe().T
# Out:
#              count        mean         std    min     25%     50%     75%  \
# recency    19945.0  134.458360  103.281149   2.00   43.00  111.00  202.00
# frequency  19945.0    5.024768    4.742707   2.00    3.00    4.00    6.00
# monetary   19945.0  751.244287  895.402173  44.98  339.98  545.27  897.78
#
#                max
# recency      367.0
# frequency    202.0
# monetary   45905.1

# %% [markdown]
# ## Görev 3: RF Skorunun Hesaplanması

# %% [markdown]
# ### Adım 1: Recency, Frequency ve Monetary metriklerini qcut yardımı ile 1-5 arasında skorlara çeviriniz.

# %% [markdown]
# ### Adım 2: Bu skorları recency_score, frequency_score ve monetary_score olarak kaydediniz.

# %%
rfm['recency_score'] = pd.qcut(rfm['recency'], 5, labels=[5, 4, 3, 2, 1])

# %%
rfm['frequency_score'] = pd.qcut(rfm['frequency'].rank(method='first'), 5, labels=[1, 2, 3, 4, 5])

# %%
rfm['monetary_score'] = pd.qcut(rfm['monetary'], 5, labels=[1, 2, 3, 4, 5])

# %%
rfm.head()
# Out:
#                             customer_id  recency  frequency  monetary  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f     95.0        5.0    939.37
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f    105.0       21.0   2013.55
# 2  69b69676-1a40-11ea-941b-000d3a38a36f    186.0        5.0    585.32
# 3  1854e56c-491f-11eb-806e-000d3a38a36f    135.0        2.0    121.97
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f     86.0        2.0    209.98
#
#   recency_score frequency_score monetary_score
# 0             3               4              4
# 1             3               5              5
# 2             2               4              3
# 3             3               1              1
# 4             3               1              1

# %% [markdown]
# ### Adım 3: recency_score ve frequency_score'u tek bir değişken olarak ifade ediniz ve rf_score olarak kaydediniz.

# %%
rfm['rfm_score'] = (rfm['recency_score'].astype(str) + rfm['frequency_score'].astype(str))

# %%
rfm.head()
# Out:
#                             customer_id  recency  frequency  monetary  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f     95.0        5.0    939.37
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f    105.0       21.0   2013.55
# 2  69b69676-1a40-11ea-941b-000d3a38a36f    186.0        5.0    585.32
# 3  1854e56c-491f-11eb-806e-000d3a38a36f    135.0        2.0    121.97
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f     86.0        2.0    209.98
#
#   recency_score frequency_score monetary_score rfm_score
# 0             3               4              4        34
# 1             3               5              5        35
# 2             2               4              3        24
# 3             3               1              1        31
# 4             3               1              1        31

# %% [markdown]
# ## Görev 4: RF Skorunun Segment Olarak Tanımlanması

# %% [markdown]
# ### Adım 1: Oluşturulan RF skorları için segment tanımlamaları yapınız.

# %% [markdown]
# ### Adım 2: Aşağıdaki seg_map yardımı ile skorları segmentlere çeviriniz.

# %%
seg_map = {
    r'[1-2][1-2]':'hibernating',
    r'[1-2][3-4]':'at_risk',
    r'[1-2]5':'cant_loose',
    r'3[1-2]':'about_to_sleep',
    r'33':'need_attention',
    r'[3-4][4-5]':'loyal_customers',
    r'41':'promising',
    r'51':'new_customers',
    r'[4-5][2-3]':'potential_loyalists',
    r'5[4-5]':'champions',
}

# %%
rfm['segment'] = rfm['rfm_score'].replace(seg_map, regex = True)

# %%
rfm.head()
# Out:
#                             customer_id  recency  frequency  monetary  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f     95.0        5.0    939.37
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f    105.0       21.0   2013.55
# 2  69b69676-1a40-11ea-941b-000d3a38a36f    186.0        5.0    585.32
# 3  1854e56c-491f-11eb-806e-000d3a38a36f    135.0        2.0    121.97
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f     86.0        2.0    209.98
#
#   recency_score frequency_score monetary_score rfm_score          segment
# 0             3               4              4        34  loyal_customers
# 1             3               5              5        35  loyal_customers
# 2             2               4              3        24          at_risk
# 3             3               1              1        31   about_to_sleep
# 4             3               1              1        31   about_to_sleep

# %% [markdown]
# ## Görev 5: Aksiyon Zamanı!

# %% [markdown]
# ### Adım 1: Segmentlerin recency, frequency ve monetary ortalamalarını inceleyiniz.

# %%
rfm.groupby('segment').mean()
# Out:
# C:\Users\myboz\AppData\Local\Temp\ipykernel_106280\322691530.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rfm.groupby('segment').mean()
#                         recency  frequency     monetary
# segment
# about_to_sleep       113.785144   2.401473   359.008963
# at_risk              241.606835   4.472373   646.610236
# cant_loose           235.444167  10.698333  1474.468217
# champions             17.106625   8.934265  1406.625109
# hibernating          247.949501   2.394007   366.267062
# loyal_customers       82.594763   8.374591  1216.818616
# need_attention       113.828676   3.727825   562.142965
# new_customers         17.917647   2.000000   339.955544
# potential_loyalists   37.155888   3.304289   533.184466
# promising             58.921175   2.000000   335.672705

# %% [markdown]
# ### Adım 2: RFM analizi yardımıyla aşağıda verilen 2 case için ilgili profildeki müşterileri bulun ve müşteri id'lerini csv olarak kaydedin.

# %% [markdown]
# a) FLO bünyesine yeni bir kadın ayakkabı markası dahil ediyor. Dahil ettiği markanın ürün fiyatları genel müşteri tercihlerinin üstünde. Bu nedenle markanın tanıtımı ve ürün satışları için ilgilenecek profildeki müşterilerle özel olarak iletişime geçmek isteniyor. Sadık müşterilerinden (champions, loyal_customers) ve kadın kategorisinden alışveriş yapan kişiler özel olarak iletişim kurulacak müşteriler. Bu müşterilerin id numaralarını csv dosyasına kaydediniz.

# %%
(rfm[rfm['segment'].isin(['champions', 'loyal_customers'])][['customer_id']]).to_csv('champions_loyals.csv')

# %% [markdown]
# b) Erkek ve çocuk ürünlerinde %40'a yakın indirim planlanmaktadır. Bu indirimle ilgili kategorilerle ilgilenen geçmişte iyi müşteri olan ama uzun süredir alışveriş yapmayan kaybedilmemesi gereken müşteriler, uykuda olanlar ve yeni gelen müşteriler özel olarak hedef alınmak isteniyor. Uygun profildeki müşterilerin id'lerini csv dosyasına kaydediniz.

# %%
(rfm[rfm['segment'].isin(['about_to_sleep', 'cant_loose', 'new_customers'])][['customer_id']]).to_csv('40pct_discount.csv')
